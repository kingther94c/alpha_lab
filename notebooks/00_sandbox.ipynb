# %% [markdown]
# # alpha_lab sandbox
#
# Scratch notebook. Anything reusable here should move into `src/alpha_lab/`.

# %%
import numpy as np
import pandas as pd

from alpha_lab.analytics.returns import cumulative_returns, sharpe, simple_returns
from alpha_lab.utils.config import load_config
from alpha_lab.utils.paths import DATA_DIR, PROJECT_ROOT

print(PROJECT_ROOT)
print(DATA_DIR)
cfg = load_config("default")
cfg

# %%
# Tiny smoke test with fake prices
prices = pd.Series(100 * (1 + 0.001 * np.arange(10)))
rets = simple_returns(prices)
wealth = cumulative_returns(rets)
print("sharpe:", sharpe(rets))
wealth
